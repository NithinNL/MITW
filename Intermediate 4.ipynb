# %% [markdown]
# # Loops

# %% [markdown]
# - Voer onderstaande cel uit om een dataframe, lists en numpy arrays aan te maken voor de oefeningen erna.

# %%
#Creating lists from columns in dataframe
import pandas as pd
import numpy as np
storedata = pd.read_csv('storedata_clean.csv',sep=";")
storedata.rename(columns={'Profit': 'Turnover'}, inplace=True)

#Creating lists from dataframe
turnover = storedata['Turnover'].values.tolist()
staff = storedata['Staff'].values.tolist()
floor = storedata['Floor Space'].values.tolist()
comp_sc = storedata['Competition score'].values.tolist()
comp_no = storedata['Competition number'].values.tolist()
min30 = storedata['30 min population'].values.tolist()

# creating numpy arrays
np_to = np.array(turnover)
np_floor = np.array(floor)
np_comp_sc = np.array(comp_sc)
np_comp_no = np.array(comp_no)

# %% [markdown]
# ## 1 Loops & Lists
# ### 1.1 For loops & lists
#
# - Maak een for loop die itereert over de elementen in de floor list. In deze loop vindt het volgende plaats:
#      - de elementen (oppervlaktes) worden opgeteld en toegewezen aan de variabele total_floor.
#      - Als de loop klaar is dan bevat total_floor de totale oppervlakte van alle winkels tezamen.
# - Bepaal het aantal elementen in floor met behulp van een functie.
# - Print de totale oppervlakte, het aantal winkels en de gemiddelde oppervlakte.

# %%
total_floor = 0
#start coding here:
for i in floor:
    total_floor += i
print(total_floor)

display(len(floor))

print("    De totale oppervlakte is: " + str(total_floor)
     + "\n       Het aantal winkels is: " + str(len(np.unique(storedata["Store ID"])))
     + "\nDe gemiddelde oppervlakte is: " + str(np.round(total_floor / len(np.unique(storedata["Store ID"])), 2)))
# Out:
# 2043277
# 136
#     De totale oppervlakte is: 2043277
#        Het aantal winkels is: 136
# De gemiddelde oppervlakte is: 15024.1

# %% [markdown]
# ### 1.2 Geindexeerde for loops
# - Print de gemiddelde oppervlakte nogmaals, maa nu de functie enumerate() om een geindexeerde for loop te maken. Aan het einde van de loop bevat de index variabele het aantal elementen in de lijst.
# - Gebruik onder andere deze variabele om de gemiddelde oppervlakte te berekenen.

# %%
total_floor = 0

for index, i in enumerate(floor):
    total_floor += i

print(round(total_floor / (index+1), 2))
# Out:
# 15024.1

# %% [markdown]
# ### 1.3 loopen over lists binnen lists.
# - Maak een for loop die over de sublists in fl_sp itereert.
# - Bij iedere iteratie wordt het volgende geprint: "x has a floor space of y sqm". Hierbij is x de plaatsnaam en y de oppervlakte.

# %%
fl_sp = [['swinton', 18526], ['stamford', 18569], ['skipton', 12288], ['stratton', 17092], ['shepperton', 11307]]
#Start coding here
for i in fl_sp:
    print(str(i[0]) + " has a floor space of " + str(i[1]) + " sqm")
# Out:
# swinton has a floor space of 18526 sqm
# stamford has a floor space of 18569 sqm
# skipton has a floor space of 12288 sqm
# stratton has a floor space of 17092 sqm
# shepperton has a floor space of 11307 sqm

# %% [markdown]
# ## 2 Loops & dictionaries
# - Voer onderstaande cel uit om de st_to dictionary aan te maken.
# - Hierin vind je de omzet per winkel.

# %%
#Creating dictionary from columns in dataframe
store_id = storedata['Store ID'].values.tolist()
turnover = storedata['Turnover'].values.tolist()
floor = storedata['Floor Space'].values.tolist()

st_to = dict(zip(store_id, turnover))
display(st_to)
# Out:
# {1437: 3410865,
#  1544: 4034051,
#  2039: 2297810,
#  2055: 2398990,
#  2141: 2288235,
#  2309: 3058134,
#  3800: 2793160,
#  4214: 3345936,
#  4857: 3117205,
#  4860: 3153278,
#  7491: 3056804,
#  7566: 1801619,
#  8207: 3797953,
#  9171: 3138911,
#  11440: 2724068,
#  13132: 2382751,
#  13984: 3321899,
#  14359: 2803867,
#  14421: 3640627,
#  14984: 3075352,
#  15125: 3491993,
#  16727: 3252148,
#  16741: 3041618,
#  18554: 3737466,
#  19296: 4217291,
#  20304: 2008363,
#  20971: 3516397,
#  21359: 3957233,
#  23025: 2942839,
#  23231: 2242288,
#  23249: 2616387,
#  23705: 2493975,
#  24174: 2203994,
#  24618: 2458785,
#  24737: 4253984,
#  26307: 4185306,
#  29319: 4160531,
#  32610: 3100521,
#  34686: 3246954,
#  35207: 2085733,
#  35944: 3741911,
#  36979: 2506748,
#  37708: 2393869,
#  37916: 4137224,
#  40352: 3572475,
#  40676: 3121837,
#  41475: 2799074,
#  42172: 2707402,
#  42797: 4176642,
#  42943: 1829621,
#  43044: 2681110,
#  43066: 2411437,
#  44476: 4300537,
#  44722: 3758014,
#  45223: 2234201,
#  45547: 2342229,
#  45577: 2104028,
#  46116: 2406120,
#  47290: 2839607,
#  48341: 2831103,
#  50703: 3032277,
#  51992: 3625088,
#  52414: 2196757,
#  54193: 3336417,
#  55138: 2779994,
#  55717: 3175101,
#  55895: 4587304,
#  55967: 3029751,
#  56056: 1512452,
#  56595: 3418735,
#  56930: 2526616,
#  57418: 2333940,
#  58249: 3197934,
#  58882: 3135133,
#  59280: 3822904,
#  59431: 2538362,
#  59517: 1855427,
#  59653: 2260838,
#  59794: 3524409,
#  60116: 3709026,
#  61950: 3337861,
#  62022: 2407898,
#  62586: 3260276,
#  63017: 1792809,
#  64781: 2804353,
#  65437: 2869330,
#  65659: 2422936,
#  66482: 4237135,
#  66844: 3007050,
#  67041: 4018966,
#  67403: 2553461,
#  67717: 3817558,
#  67825: 2405770,
#  67831: 1764019,
#  68816: 4793593,
#  69540: 2896362,
#  73474: 3192066,
#  74421: 3092180,
#  74620: 2419983,
#  74958: 2701564,
#  76653: 3606536,
#  76773: 3304795,
#  77163: 3663843,
#  77644: 3965957,
#  78305: 2651301,
#  78368: 3487542,
#  78904: 2004312,
#  79413: 3102538,
#  81258: 2291029,
#  82709: 3895318,
#  82754: 3741407,
#  83250: 2604575,
#  83312: 1648919,
#  83479: 1665527,
#  83480: 3654694,
#  84225: 3598894,
#  85185: 2172265,
#  85476: 2397407,
#  87212: 2329927,
#  87510: 3444876,
#  88442: 2564358,
#  88942: 2534145,
#  90621: 2956061,
#  90995: 2467943,
#  91085: 3891535,
#  92341: 3498966,
#  92768: 2872001,
#  93212: 3501093,
#  93991: 3774401,
#  95915: 3584813,
#  96852: 2561019,
#  96853: 2581954,
#  96858: 2589339,
#  98062: 2583755,
#  98923: 950924,
#  99854: 3485295}

# %% [markdown]
# ### 2.1  Loopen over een dictionary
# - Maak een for loop die over de items in st_to itereert waarbij alle omzetten bij elkaar worden opgeteld en toegewezen aan de variabele total_to.
# - Tel tijdens iedere iteratie 1 op bij de variabele number.
# - Print de totale omzet, het aantal winkels en de gemiddelde omzet. De gemiddelde omzet wordt afgedrukt als een integer.

# %%
total_to = 0
number = 0
#start coding here
for i in st_to.items():
    total_to += i[1]
    number += 1
print(total_to)
print(number)
print(round(total_to/number, 2))
# Out:
# 406773409
# 136
# 2990980.95

# %% [markdown]
# ## 3 Loops & numpy arrays
# - Aan het begin van dit bestand is de Numpy array np_floor aangemaakt.

# %% [markdown]
# ### 3.1 Loopen over een numpy array
# - Maak een for loop die itereert over de elementen np_floor. In deze loop vindt het volgende plaats:
#      - de elementen (oppervlaktes) worden opgeteld en toegewezen aan de variabele np_total_floor.
#      - Als de loop klaar is dan bevat np_total_floor de totale oppervlakte van alle winkels tezamen.
#      - Tel tijdens iedere iteratie 1 op bij de variabele number.
# - Bereken de gemiddelde oppervlakte met de variabelen np_total_floor en number. Wijs het resultaat toe aan de variabele avg.
# - Bereken de gemiddelde oppervlakte met een numpy functie. Wijs dit resultaat toe aan avg_alt.
# - Welke wijze van gemiddelde berekeken verdient de voorkeur? Waarom?

# %%
np_total_floor = 0
number = 0
for i in np_floor:
    np_total_floor += i
    number += 1
avg = np_total_floor / number
avg_alt= np.average(np_floor)

print(avg)
print(avg_alt)

# Ik heb de voorkeur voor de functie, omdat een functienaam herkenbaar is en daarmee de leesbaarheid vergroot.
# Out:
# 15024.095588235294
# 15024.095588235294

# %% [markdown]
# ## 4 Loops & Dataframes
# ### 4.1 loopen over een Pandas dataframe
# - Maak een for loop die itereert over de elementen van storedata en de oppervlaktes optelt en toewijs aan de variabele pd_total_floor.
# - Tel tijdens iedere iteratie 1 op bij de variabele number.
# - Gebruik pd_total_floor en number om het gemiddelde uit te rekenen en toe te wijzen aan de variable avg.
# - Print avg.

# %%
pd_total_floor = 0
number = 0
for i, j in storedata.iterrows():
    pd_total_floor += (j["Floor Space"])
    number += 1
avg = round(pd_total_floor / number, 2)
print(avg)
# Out:
# 15024.1

# %% [markdown]
# ## 5 Integratie
# ### 5.1 control flow en loops
# - Gebruik een for loop om de nieuwe kolom 'Turnover Floor' aan te maken in het storedata dataframe. Toon in deze kolom de omzet (Turnover) per vierkante meter (Floor Space).
# - Pas control flow (if, else en/of elif) toe in de loop om de kolom 'Performance' aan te maken:
#     - Als de omzet per vierkante meter hoger is dan 210 dan is de performance 'Very Good'.
#     - Als de omzet per vierkante meter hoger is dan 200 dan is de performance 'Good'.
#     - In alle andere gevallen is de performance 'Poor'.
# - Toon de nieuwe kolommen.

# %%
storedata["Turnover_Floor"] = (round(storedata["Turnover"] / storedata["Floor Space"], 2))
for i, j in storedata.iterrows():
    if j["Turnover_Floor"] > 210:
        storedata.loc[i, "Performance"] = "Very Good"
    elif j["Turnover_Floor"] > 200:
        storedata.loc[i, "Performance"] = "Good"
    else:
        storedata.loc[i, "Performance"] = "Poor"
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# 0          18526     121      Yes                 10      Retail Park  ...
# 1          18569     121      Yes                 11  Shopping Centre  ...
# 2          12288     105       No                 12      Retail Park  ...
# 3          17092     117       No                 14      High Street  ...
# 4          11307     103       No                 18      Retail Park  ...
# ..           ...     ...      ...                ...              ...  ...
# 131        14120     110      Yes                 13      Retail Park  ...
# 132        11205     103       No                 15  Shopping Centre  ...
# 133        16190     115       No                 19  Shopping Centre  ...
# 134        15516     113       No                 17      High Street  ...
# 135        14468     111      Yes                 18      High Street  ...
#
#      30 min population  20 min population  10 min population  Store age  \
# 0              1138224            1006986            1002340          3
# 1              1015321            1012182            1008436          4
# 2              1281661            1104490            1011395         11
# 3              1022959            1009496            1002169          5
# 4              1085170            1003137            1002513          7
# ..                 ...                ...                ...        ...
# 131            1240813            1141898            1041041          6
# 132            1424404            1378708            1160929          5
# 133            1359511            1200486            1063718          7
# 134            1245725            1127276            1045154         11
# 135            1307752            1159859            1020940          8
#
#      Clearance space  Competition number  Competition score  Turnover  \
# 0                238                  16                 16   3410865
# 1                384                  15                 19   4034051
# 2                219                  13                 18   2297810
# 3                261                  15                 12   2398990
# 4                200                  19                 13   2288235
# ..               ...                 ...                ...       ...
# 131              202                  18                 14   2581954
# 132              203                  13                 18   2589339
# 133              341                  18                 18   2583755
# 134              261                  14                 10    950924
# 135              276                  18                 13   3485295
#
#      Performance Turnover_Floor
# 0           Poor         184.11
# 1      Very Good         217.25
# 2           Poor         187.00
# 3           Poor         140.36
# 4           Good         202.37
# ..           ...            ...
# 131         Poor         182.86
# 132    Very Good         231.09
# 133         Poor         159.59
# 134         Poor          61.29
# 135    Very Good         240.90
#
# [136 rows x 21 columns]

# %% [markdown]
# ### 5.2 Nieuwe kolom zonder for loop
# - Maak een nieuwe kolom 'Turnover Staff' ZONDER een for loop waarin de omzet per medewerker (Staff) staat.

# %%
storedata["Turnover Staff 2"] = (storedata["Turnover"] / storedata["Staff"]).astype("int")
storedata.head(9)
# Out:
#                             Town Country  Store ID Manager name  Staff  \
# 0   Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                       Stamford      UK      1544         Ella      8
# 2                        Skipton      UK      2039    Valentina      2
# 3                       Stratton      UK      2055      Antonia      7
# 4                     Shepperton      UK      2141      Gabriel      7
# 5                      Southwell      UK      2309        Sarah      7
# 6      Swinton (South Yorkshire)      UK      3800        James      8
# 7                 Sowerby Bridge      UK      4214       Ashley      9
# 8                      Sheffield      UK      4857    Guilherme      9
#
#    Floor Space  Window Car park  Demographic score         Location  ...  \
# 0        18526     121      Yes                 10      Retail Park  ...
# 1        18569     121      Yes                 11  Shopping Centre  ...
# 2        12288     105       No                 12      Retail Park  ...
# 3        17092     117       No                 14      High Street  ...
# 4        11307     103       No                 18      Retail Park  ...
# 5        17888     119      Yes                 19      Retail Park  ...
# 6        13814     109      Yes                 17      High Street  ...
# 7        15643     114        Y                 11      Retail Park  ...
# 8        13869     109      Yes                 12  Shopping Centre  ...
#
#    10 min population  Store age  Clearance space  Competition number  \
# 0            1002340          3              238                  16
# 1            1008436          4              384                  15
# 2            1011395         11              219                  13
# 3            1002169          5              261                  15
# 4            1002513          7              200                  19
# 5            1193318          2              394                  17
# 6            1000844          5              228                  11
# 7            1000319          4              258                  12
# 8            1057921          9              217                  19
#
#    Competition score  Turnover  Performance  Turnover_Floor  Turnover Staff  \
# 0                 16   3410865         Poor          184.11          378985
# 1                 19   4034051    Very Good          217.25          504256
# 2                 18   2297810         Poor          187.00         1148905
# 3                 12   2398990         Poor          140.36          342712
# 4                 13   2288235         Good          202.37          326890
# 5                 11   3058134         Poor          170.96          436876
# 6                 14   2793160         Good          202.20          349145
# 7                 16   3345936    Very Good          213.89          371770
# 8                 14   3117205    Very Good          224.76          346356
#
#   Turnover Staff 2
# 0           378985
# 1           504256
# 2          1148905
# 3           342712
# 4           326890
# 5           436876
# 6           349145
# 7           371770
# 8           346356
#
# [9 rows x 23 columns]

# %% [markdown]
# ### 5.3 Dictionary maken met for loop
# - Maak met een for-loop de dictionary st_num aan waarin je laat zien hoeveel winkels er zijn per aantal medewerkers ('Staff'). Er zijn bijvoorbeeld 28 winkels met 9 medewerkers. De dictionary dient er als volgt uit te zien: {9: 28, 8: 18, 2: 1, 7: 29, 5: 29, 6: 30, 3: 1}

# %%
staff_stores = (storedata[["Store ID", "Staff"]].groupby(["Staff"]).count().reset_index())
st_num = {}
for i in range(len(staff_stores["Staff"])):
    st_num[staff_stores["Staff"][i]] = staff_stores["Store ID"][i]
print(st_num)
# Out:
# {2: 1, 3: 1, 5: 29, 6: 30, 7: 29, 8: 18, 9: 28}

# %%
st_num = {}
for i in storedata["Staff"]:
    st_num[i] = storedata["Staff"].value_counts()[i]
st_num
# Out:
# {9: 28, 8: 18, 2: 1, 7: 29, 5: 29, 6: 30, 3: 1}
